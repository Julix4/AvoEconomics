# %% [markdown]
# ##EDA
#
# A continuación realizaremos el EDA de los distintos datasets.

# %%
#Cargar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #plots
plt.rcParams['figure.figsize'] = 20, 15

import sys
import os

# Añade el directorio raíz del proyecto al sys.path
sys.path.append(os.path.abspath('./'))

# %%
#Importar los datasets
df_avocado = pd.read_csv('data/avocado.csv').copy()
df_producer_prices = pd.read_csv('data/FAOSTAT_data_avocado_Producer_Prices.csv').copy()
df_livestock = pd.read_csv('data/FAOSTAT_Crops and livestock products.csv').copy()

# %% [markdown]
# ##df_avocado

# %%
df_avocado.info()
df_avocado.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
import sys
import os

# Agrega la ruta raíz al sys.path
project_root = os.path.abspath('.')  # Usa el directorio actual
if project_root not in sys.path:
    sys.path.append(project_root)

# Verifica las rutas
print(sys.path)
# Out:
# ['c:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'c:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'c:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'c:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312', '', 'C:\\Users\\User\\AppData\\Roaming\\Python\\Python312\\site-packages', 'C:\\Users\\User\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32', 'C:\\Users\\User\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32\\lib', 'C:\\Users\\User\\AppData\\Roaming\\Python\\Python312\\site-packages\\Pythonwin', 'c:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages', 'c:\\Backup 082021\\España\\Cibernarium\\UOC\\Proyecto 3 - Aguacate\\AvoEconomics', 'c:\\Backup 082021\\España\\Cibernarium\\UOC\\Proyecto 3 - Aguacate\\AvoEconomics']

# %%
# importar funciones
from utils.def_classify_location import get_group_location
from utils.def_region_classification import get_region_classification

# %%
# Llamar a las funciones creadas en utils, para la selección de la región de estudio.
df_avocado_hotels = df_avocado.copy()

# Crear la columna 'region_type'
df_avocado_hotels['region_type'] = df_avocado_hotels['region'].apply(get_region_classification)
# Crear la columna 'location'
df_avocado_hotels['location'] = df_avocado_hotels['region'].apply(get_group_location)

# %%
df_avocado_hotels['location'].unique()
# Out:
# array(['newyork', 'louisiana', 'otros', 'texas', 'florida', 'california',
#        'TotalUS'], dtype=object)

# %%
# Filtrar el dataset por la region de estudio
df_avocado_hotels = df_avocado_hotels[df_avocado_hotels["location"].isin(['newyork', 'texas', 'louisiana', 'florida', 'california',])]

# %%
df_avocado_hotels.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
# 5   43.61     6683.91     6556.47      127.44          0.0  conventional
# 6   93.26     8318.86     8196.81      122.05          0.0  conventional
# 7   80.00     6829.22     6266.85      562.37          0.0  conventional
# 8   85.34    11388.36    11104.53      283.83          0.0  conventional
# 9  113.00     8625.92     8061.47      564.45          0.0  conventional
#
#    year  region region_type location
# 0  2015  Albany        City  newyork
# 1  2015  Albany        City  newyork
# 2  2015  Albany        City  newyork
# 3  2015  Albany        City  newyork
# 4  2015  Albany        City  newyork
# 5  2015  Albany        City  newyork
# 6  2015  Albany        City  newyork
# 7  2015  Albany        City  newyork
# 8  2015  Albany        City  newyork
# 9  2015  Albany        City  newyork

# %%
df_avocado_hotels.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region', 'region_type', 'location'],
#       dtype='object')

# %%
df_avocado_hotels = df_avocado_hotels[['Date', 'AveragePrice', 'Total Volume', '4046', '4225',
       '4770','type', 'year', 'region','location']]
df_avocado_hotels.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770', 'type',
#        'year', 'region', 'location'],
#       dtype='object')

# %%
df_avocado_hotels.nunique()
# Out:
# Date             169
# AveragePrice     233
# Total Volume    3718
# 4046            3709
# 4225            3646
# 4770            2074
# type               2
# year               4
# region            11
# location           5
# dtype: int64

# %% [markdown]
# ##EDA df_producer_prices y df_livestock

# %%
df_producer_prices.info()
df_producer_prices.describe()
df_producer_prices.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       71 non-null     object
#  1   Domain            71 non-null     object
#  2   Area Code (M49)   71 non-null     int64
#  3   Area              71 non-null     object
#  4   Element Code      71 non-null     int64
#  5   Element           71 non-null     object
#  6   Item Code (CPC)   71 non-null     int64
#  7   Item              71 non-null     object
#  8   Year Code         71 non-null     int64
#  9   Year              71 non-null     int64
#  10  Months Code       71 non-null     int64
#  11  Months            71 non-null     object
#  12  Unit              71 non-null     object
#  13  Value             71 non-null     float64
#  14  Flag              71 non-null     object
#  15  Flag Description  71 non-null     object
# dtypes: float64(1), int64(6), object(9)
# memory usage: 9.0+ KB
#   Domain Code           Domain  Area Code (M49)  \
# 0          PP  Producer Prices               68
# 1          PP  Producer Prices               68
# 2          PP  Producer Prices               68
# 3          PP  Producer Prices               76
# 4          PP  Producer Prices               76
# 5          PP  Producer Prices               76
# 6          PP  Producer Prices               76
# 7          PP  Producer Prices               76
# 8          PP  Producer Prices              152
# 9          PP  Producer Prices              152
#
#                                Area  Element Code                     Element  \
# 0  Bolivia (Plurinational State of)          5532  Producer Price (USD/tonne)
# 1  Bolivia (Plurinational State of)          5532  Producer Price (USD/tonne)
# 2  Bolivia (Plurinational State of)          5532  Producer Price (USD/tonne)
# 3                            Brazil          5532  Producer Price (USD/tonne)
# 4                            Brazil          5532  Producer Price (USD/tonne)
# 5                            Brazil          5532  Producer Price (USD/tonne)
# 6                            Brazil          5532  Producer Price (USD/tonne)
# 7                            Brazil          5532  Producer Price (USD/tonne)
# 8                             Chile          5532  Producer Price (USD/tonne)
# 9                             Chile          5532  Producer Price (USD/tonne)
#
#    Item Code (CPC)      Item  Year Code  Year  Months Code        Months Unit  \
# 0             1311  Avocados       2020  2020         7021  Annual value  USD
# 1             1311  Avocados       2021  2021         7021  Annual value  USD
# 2             1311  Avocados       2022  2022         7021  Annual value  USD
# 3             1311  Avocados       2018  2018         7021  Annual value  USD
# 4             1311  Avocados       2019  2019         7021  Annual value  USD
# 5             1311  Avocados       2020  2020         7021  Annual value  USD
# 6             1311  Avocados       2021  2021         7021  Annual value  USD
# 7             1311  Avocados       2022  2022         7021  Annual value  USD
# 8             1311  Avocados       2018  2018         7021  Annual value  USD
# 9             1311  Avocados       2019  2019         7021  Annual value  USD
#
#     Value Flag Flag Description
# 0  2585.6    A  Official figure
# 1  2589.2    A  Official figure
# 2  2749.6    A  Official figure
# 3   366.3    A  Official figure
# 4   377.7    A  Official figure
# 5   344.3    A  Official figure
# 6   437.6    A  Official figure
# 7   490.7    A  Official figure
# 8  3245.9    A  Official figure
# 9  2985.7    A  Official figure

# %%
df_producer_prices = df_producer_prices[['Area Code (M49)', 'Area', 'Element', 'Year','Unit', 'Value', ]]

# %%
#df_livestock.info()
#df_livestock.describe()
#df_livestock.head(20)

# %%
# Filtramos 'Element Code' es 5910 o 5922, solo exportaciones
filtered_df = df_livestock[df_livestock['Element Code'].isin([5910, 5922])]

filtered_df.info()
filtered_df.describe()
filtered_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 440 entries, 18 to 905
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area Code (M49)  440 non-null    int64
#  1   Area             440 non-null    object
#  2   Element Code     440 non-null    int64
#  3   Element          440 non-null    object
#  4   Year             440 non-null    int64
#  5   Unit             440 non-null    object
#  6   Value            440 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 27.5+ KB
#     Area Code (M49)       Area  Element Code          Element  Year      Unit  \
# 18               32  Argentina          5910  Export Quantity  2015         t
# 19               32  Argentina          5922     Export Value  2015  1000 USD
# 22               32  Argentina          5910  Export Quantity  2016         t
# 23               32  Argentina          5922     Export Value  2016  1000 USD
# 26               32  Argentina          5910  Export Quantity  2017         t
# 27               32  Argentina          5922     Export Value  2017  1000 USD
# 56               52   Barbados          5910  Export Quantity  2015         t
# 57               52   Barbados          5922     Export Value  2015  1000 USD
# 60               52   Barbados          5910  Export Quantity  2016         t
# 61               52   Barbados          5922     Export Value  2016  1000 USD
#
#      Value
# 18   84.18
# 19  217.00
# 22  142.60
# 23  237.00
# 26   12.62
# 27   30.00
# 56   28.06
# 57   47.00
# 60   13.57
# 61   21.00

# %%
df_livestock = df_livestock[['Area Code (M49)', 'Area','Element Code',
       'Element','Year', 'Unit','Value']]
