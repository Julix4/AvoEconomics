# %% [markdown]
# ##EDA
#
# A continuación realizaremos el EDA de los distintos datasets.

# %%
#Cargar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #plots
plt.rcParams['figure.figsize'] = 20, 15

import sys
import os

# Añade el directorio raíz del proyecto al sys.path
sys.path.append(os.path.abspath('./'))

# %%
#Importar los datasets
df_avocado = pd.read_csv('data/avocado.csv').copy()
df_producer_prices = pd.read_csv('data/FAOSTAT_data_avocado_Producer_Prices.csv').copy()
df_livestock = pd.read_csv('data/FAOSTAT_Crops and livestock products.csv').copy()

# %% [markdown]
# ##df_avocado

# %%
df_avocado.info()
df_avocado.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# ...

# %%
import sys
import os

# Agrega la ruta raíz al sys.path
project_root = os.path.abspath('.')  # Usa el directorio actual
if project_root not in sys.path:
    sys.path.append(project_root)

# Verifica las rutas
print(sys.path)
# Out:
# ['/Users/juli/uoc/02_intensivoUOC/git/AvoEconomics', '/opt/anaconda3/lib/python39.zip', '/opt/anaconda3/lib/python3.9', '/opt/anaconda3/lib/python3.9/lib-dynload', '', '/opt/anaconda3/lib/python3.9/site-packages', '/opt/anaconda3/lib/python3.9/site-packages/aeosa', '/opt/anaconda3/lib/python3.9/site-packages/setuptools/_vendor', '/Users/juli/uoc/02_intensivoUOC/git/AvoEconomics']

# %%
# importar funciones
from utils.def_classify_location import get_group_location
from utils.def_region_classification import get_region_classification

# %%
# Llamar a las funciones creadas en utils, para la selección de la región de estudio.
df_avocado_hotels = df_avocado.copy()

# Crear la columna 'region_type'
df_avocado_hotels['region_type'] = df_avocado_hotels['region'].apply(get_region_classification)
# Crear la columna 'location'
df_avocado_hotels['location'] = df_avocado_hotels['region'].apply(get_group_location)

# %%
df_avocado_hotels['location'].unique()
# Out:
# array(['newyork', 'louisiana', 'otros', 'texas', 'florida', 'california',
#        'TotalUS'], dtype=object)

# %%
# Filtrar el dataset por la region de estudio
df_avocado_hotels = df_avocado_hotels[df_avocado_hotels["location"].isin(['newyork', 'texas', 'louisiana', 'florida', 'california',])]

# %%
df_avocado_hotels.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %%
# Agregamos nuevas columnas al DataFrame df_avocado_hotels

# Calculo la cantidad de aguacates en función del tipo
df_avocado_hotels['cantidad_aguacates'] = df_avocado_hotels.apply(
    lambda row: row['Total Volume'] / (0.25 if row['type'] == 'conventional' else 0.3),
    axis=1
)

# Calculo cantidad de toneladas
df_avocado_hotels['cant_toneladas'] = (df_avocado_hotels['Total Volume'] / 1000).round(2)

# Calcular el precio por tonelada
df_avocado_hotels['precio_tonelada'] = (
    (df_avocado_hotels['AveragePrice'] * df_avocado_hotels['cantidad_aguacates']) / df_avocado_hotels['cant_toneladas']
)

# Mostrar las primeras filas del DataFrame con las nuevas columnas
df_avocado_hotels.info()
df_avocado_hotels.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3718 entries, 0 to 18116
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                3718 non-null   object
#  1   AveragePrice        3718 non-null   float64
#  2   Total Volume        3718 non-null   float64
#  3   4046                3718 non-null   float64
#  4   4225                3718 non-null   float64
#  5   4770                3718 non-null   float64
#  6   type                3718 non-null   object
#  7   year                3718 non-null   int64
#  8   region              3718 non-null   object
#  9   location            3718 non-null   object
#  10  cantidad_aguacates  3718 non-null   float64
#  11  cant_toneladas      3718 non-null   float64
#  12  precio_tonelada     3718 non-null   float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 406.7+ KB
# ...

# %%
# Elección de las columnas de interés para el análisis
df_avocado_hotels = df_avocado_hotels[['Date', 'AveragePrice', 'Total Volume', '4046', '4225',
       '4770','type', 'year', 'region','location']]
df_avocado_hotels.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770', 'type',
#        'year', 'region', 'location'],
#       dtype='object')

# %%
df_avocado_hotels.nunique()
# Out:
# Date             169
# AveragePrice     233
# Total Volume    3718
# 4046            3709
# 4225            3646
# 4770            2074
# type               2
# year               4
# region            11
# location           5
# dtype: int64

# %% [markdown]
# ##EDA df_producer_prices y df_livestock

# %%
df_producer_prices.info()
df_producer_prices.describe()
df_producer_prices.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       108 non-null    object
#  1   Domain            108 non-null    object
#  2   Area Code (M49)   108 non-null    int64
#  3   Area              108 non-null    object
#  4   Element Code      108 non-null    int64
#  5   Element           108 non-null    object
#  6   Item Code (CPC)   108 non-null    int64
#  7   Item              108 non-null    object
#  8   Year Code         108 non-null    int64
#  9   Year              108 non-null    int64
#  10  Months Code       108 non-null    int64
#  11  Months            108 non-null    object
#  12  Unit              108 non-null    object
#  13  Value             108 non-null    float64
#  14  Flag              108 non-null    object
#  15  Flag Description  108 non-null    object
# ...

# %%
# Elección de las columnas principales para el análisis posterior
df_producer_prices = df_producer_prices[['Area Code (M49)', 'Area', 'Element', 'Year','Unit', 'Value', ]]

# %%
# Filtramos 'Element Code' es 5910 o 5922, solo exportaciones
df_livestock = df_livestock[df_livestock['Element Code'].isin([5910, 5922])]

df_livestock['Element Code'].head(10)
# Out:
# 18    5910
# 19    5922
# 22    5910
# 23    5922
# 26    5910
# 27    5922
# 56    5910
# 57    5922
# 60    5910
# 61    5922
# Name: Element Code, dtype: int64

# %%
# Elección de las columnas de interés para el análisis posterior
df_livestock = df_livestock[['Area Code (M49)', 'Area','Element Code',
       'Element','Year', 'Unit','Value']]
